# %% [markdown]
# # 1변량 모비율 가설검정

# %%
import statsmodels.stats.proportion as smp
count = 5
nobs = 83
significant level = .05
stat, pval = smp.proportions_ztest(count, nobs, significant level)
print(stat, pval)
# Out:
# 0.3921260263140161 0.6949650981148476

# %% [markdown]
# # 1변량 모비율 신뢰구간
#
# > method (string in ['normal']) – method to use for confidence interval, currently available methods:
#
# > normal : asymptotic normal approximation
#
# > agresti_coull : Agresti-Coull interval
#
# > beta : Clopper-Pearson interval based on Beta distribution
#
# > wilson : Wilson Score interval
#
# > jeffreys : Jeffreys Bayesian Interval
#
# > binom_test : experimental, inversion of binom_test

# %%
from statsmodels.stats.proportion import proportion_confint
proportion_confint(count, nobs, significant level=0.05, method='normal')
# Out:
# (0.009053542014849217, 0.11142838569599416)

# %% [markdown]
# 예제 데이터 가져오기

# %%
import pandas as pd
df=pd.read_csv('http://203.247.53.31/2015_Fall/D4BE/Bank2.csv')
df.head(3)
# Out:
#    Gender  Rate  Business  Sales  Age
# 0  Female  1.65         1    473   12
# 1  Female  0.89         1    515    9
# 2  Female  1.13         1    772   11

# %% [markdown]
# # 1변량 모평균 검정

# %%
from scipy import stats
mu0=1.2
stats.ttest_1samp(df.Rate,mu0)
# Out:
# Ttest_1sampResult(statistic=5.013290823668153, pvalue=6.275258796909992e-07)

# %% [markdown]
# # 1변량 모평균 신뢰구간

# %%
import numpy as np
import scipy.stats
def mean_confidence_interval(data,confidence):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h
mean_confidence_interval(df.Rate,0.95)
# Out:
# (1.3033618233618234, 1.262905603255761, 1.3438180434678857)
