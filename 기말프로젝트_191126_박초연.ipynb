# %%
# !pip install -U finance-datareader
import FinanceDataReader as fdr
df_krx = fdr.StockListing('KRX')
# Out:
# Requirement already up-to-date: finance-datareader in /usr/local/lib/python3.6/dist-packages (0.8.2)
# ...

# %%
import pandas as pd
import numpy as np

# %%
name=input('주식 코드 기업명 ?') #find 종목코드 및 정보
df_krx[df_krx['Name'].str.contains(name)]

# %%
KOSPI = fdr.DataReader('KS11', '2015-01-01','2019-11-25')
SAMSUNG = fdr.DataReader('005930', '2015-01-01','2019-11-25')
KEPCO = fdr.DataReader('015760', '2015-01-01','2019-11-25')
SKtelecom = fdr.DataReader('017670', '2015-01-01','2019-11-25')
POSCO = fdr.DataReader('005490', '2015-01-01','2019-11-25')
HYUNDAI = fdr.DataReader('005380', '2015-01-01','2019-11-25')

# %%
df = pd.concat([KOSPI['Close'],SAMSUNG['Close'],KEPCO['Close'],SKtelecom['Close'],POSCO['Close'],HYUNDAI['Close']], axis=1)
df.set_axis(['KOSPI','SAMSUNG','KEPCO','SKtelecom','POSCO','HYUNDAI'],axis=1,inplace=True)
#df.columns = ['KOSPI','SAMSUNG','KEPCO','SKtelecom','POSCO','HYUNDAI']

# %%
df.head(3)
# Out:
#               KOSPI  SAMSUNG  KEPCO  SKtelecom   POSCO  HYUNDAI
# Date
# 2015-01-02  1926.44    26600  42700     272500  283500   169000
# 2015-01-05  1915.75    26660  42000     276500  279000   168000
# 2015-01-06  1882.45    25900  41850     274500  275000   164500

# %%
import datetime

# %%
df['day'] = df.index.weekday_name
df['quarter'] = df.index.quarter
df['week'] = df.index.week
df['year'] = df.index.year

# %%
df.tail(3)
# Out:
#               KOSPI  SAMSUNG  KEPCO  SKtelecom  ...       day  quarter week  year
# Date                                            ...
# 2019-11-21  2096.60    51000  27900     241500  ...  Thursday        4   47  2019
# 2019-11-22  2101.96    51600  28000     244500  ...    Friday        4   47  2019
# 2019-11-25  2123.50    51800  27850     246000  ...    Monday        4   48  2019
#
# [3 rows x 10 columns]

# %% [markdown]
# # 과업0
#
# 코스피 지수 시계열 그림을 그리시오. 단, 수직 참고선은 문재인 정부 시작일 17년 5월 10일

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df.index,df[['SAMSUNG','KEPCO','SKtelecom','POSCO','HYUNDAI']])
plt.legend(df[['SAMSUNG','KEPCO','SKtelecom','POSCO','HYUNDAI']],bbox_to_anchor=(1,1))
plt.axvline(df.index[df.index=='2017-05-10'], color='r')
plt.axvline(df.index[df.index=='2016-01-04'])
plt.axvline(df.index[df.index=='2018-01-02'])
plt.axvline(df.index[df.index=='2019-01-02'])

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
